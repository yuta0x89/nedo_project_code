# %%
import json

# %%
with open("../../dataset/v0/VisualGenome/question_answers.json", "r", encoding="utf-8") as f:
    dataset = json.load(f)

# %%
dataset[:2]
# Out:
# [{'id': 2395966,
#   'qas': [{'image_id': 2395966,
#     'qa_id': 10000000,
#     'answer': 'オレンジ色',
#     'a_objects': [],
#     'question': 'バイクの車体の色はどんな色をしていますか？',
#     'q_objects': []},
#    {'image_id': 2395966,
#     'qa_id': 10000001,
#     'answer': '白色',
#     'a_objects': [],
#     'question': 'バイクを固定している器具の色はどんな色をしていますか？',
#     'q_objects': []},
#    {'image_id': 2395966,
#     'qa_id': 10000002,
#     'answer': '黒色',
#     'a_objects': [],
#     'question': 'バイクが置かれている床は何色ですか？',
#     'q_objects': []},
#    {'image_id': 2395966,
#     'qa_id': 10000003,
#     'answer': '緑色',
#     'a_objects': [],
#     'question': 'バイクの右側の通路の床は何色ですか？',
#     'q_objects': []},
#    {'image_id': 2395966,
#     'qa_id': 10000004,
#     'answer': '5つ',
#     'a_objects': [],
#     'question': 'バイクの左に落ちている箱側面に書かれたメニューはいくつですか？',
#     'q_objects': []},
#    {'image_id': 2395966,
#     'qa_id': 10000005,
#     'answer': '黒色',
#     'a_objects': [],
# ...

# %%
with open("../../dataset/v0/VisualGenome/image_data.json", "r", encoding="utf-8") as f:
    image_metadata = json.load(f)

# %%
image_metadata[:2]
# Out:
# [{'width': 800,
#   'url': 'https://cs.stanford.edu/people/rak248/VG_100K_2/1.jpg',
#   'height': 600,
#   'image_id': 1,
#   'coco_id': None,
#   'flickr_id': None},
#  {'width': 800,
#   'url': 'https://cs.stanford.edu/people/rak248/VG_100K/2.jpg',
#   'height': 600,
#   'image_id': 2,
#   'coco_id': None,
#   'flickr_id': None}]

# %%
with open("./region_descriptions.json", "r", encoding="utf-8") as f:
    region_descriptions = json.load(f)

# %%
region_descriptions[:2]
# Out:
# [{'regions': [{'region_id': 1382,
#     'width': 82,
#     'height': 139,
#     'image_id': 1,
#     'phrase': 'the clock is green in colour',
#     'y': 57,
#     'x': 421},
#    {'region_id': 1383,
#     'width': 182,
#     'height': 109,
#     'image_id': 1,
#     'phrase': 'shade is along the street ',
#     'y': 372,
#     'x': 194},
#    {'region_id': 1384,
#     'width': 61,
#     'height': 30,
#     'image_id': 1,
#     'phrase': 'man is wearing sneakers',
#     'y': 491,
#     'x': 241},
#    {'region_id': 1385,
#     'width': 36,
#     'height': 36,
#     'image_id': 1,
#     'phrase': 'cars headlights are off',
#     'y': 377,
#     'x': 617},
#    {'region_id': 1386,
#     'width': 41,
#     'height': 49,
#     'image_id': 1,
#     'phrase': 'bikes are parked at the far edge',
#     'y': 298,
#     'x': 322},
#    {'region_id': 1432,
#     'width': 84,
#     'height': 178,
#     'image_id': 1,
#     'phrase': 'A sign on the facade of the building',
#     'y': 14,
# ...
